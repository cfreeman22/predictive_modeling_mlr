# %% [markdown]
# <a href="https://colab.research.google.com/github/cfreeman22/predictive_modeling_mlr/blob/main/D208_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from patsy import dmatrices

from statsmodels.compat import lzip
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Removes the limit for the number of displayed columns
pd.set_option("display.max_columns", None)
# Sets the limit for the number of displayed rows
pd.set_option("display.max_rows", 200)

from scipy.stats import *
# to build linear regression_model
from sklearn.linear_model import LinearRegression

# to check model performance
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
import statsmodels.api as sm 
import pylab as py 
sns.set(color_codes= True)
# to compute ttest
import scipy.stats as stats
import warnings
warnings.filterwarnings('ignore')
# To get diferent metric scores
# To get diferent metric scores

# Library to split data
from sklearn.model_selection import train_test_split

# %%
# While doing uni-variate analysis of numerical variables we want to study their central tendency 
# and dispersion.
# Let us write a function that will help us create boxplot and histogram for any input numerical 
# variable.
# This function takes the numerical column as the input and returns the boxplots 
# and histograms for the variable.
# Let us see if this help us write faster and cleaner code.
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(6, 4), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
# function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
def distribution_plot_wrt_target(data, predictor, target):

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))

    target_uniq = data[target].unique()

    axs[0, 0].set_title("Distribution of target for target=" + str(target_uniq[0]))
    sns.histplot(
        data=data[data[target] == target_uniq[0]],
        x=predictor,
        kde=True,
        ax=axs[0, 0],
        color="teal",
        stat="density",
    )

    axs[0, 1].set_title("Distribution of target for target=" + str(target_uniq[1]))
    sns.histplot(
        data=data[data[target] == target_uniq[1]],
        x=predictor,
        kde=True,
        ax=axs[0, 1],
        color="orange",
        stat="density",
    )

    axs[1, 0].set_title("Boxplot w.r.t target")
    sns.boxplot(data=data, x=target, y=predictor, ax=axs[1, 0], palette="gist_rainbow")

    axs[1, 1].set_title("Boxplot (without outliers) w.r.t target")
    sns.boxplot(
        data=data,
        x=target,
        y=predictor,
        ax=axs[1, 1],
        showfliers=False,
        palette="gist_rainbow",
    )

    plt.tight_layout()
    plt.show()

# %%
# functions to treat outliers by flooring and capping


def treat_outliers(df, col):
    """
    Treats outliers in a variable

    df: dataframe
    col: dataframe column
    """
    Q1 = df[col].quantile(0.25)  # 25th quantile
    Q3 = df[col].quantile(0.75)  # 75th quantile
    IQR = Q3 - Q1
    Lower_Whisker = Q1 - 1.5 * IQR
    Upper_Whisker = Q3 + 1.5 * IQR

    # all the values smaller than Lower_Whisker will be assigned the value of Lower_Whisker
    # all the values greater than Upper_Whisker will be assigned the value of Upper_Whisker
    df[col] = np.clip(df[col], Lower_Whisker, Upper_Whisker)

    return df


def treat_outliers_all(df, col_list):
    """
    Treat outliers in a list of variables

    df: dataframe
    col_list: list of dataframe columns
    """
    for c in col_list:
        df = treat_outliers(df, c)

    return df

# %%
#reading the data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Reading the data from my google drive.
df = pd.read_csv('/content/drive/My Drive/churn_clean.csv')

# %% [markdown]
# # **Data Preparation**
# ## **Research question: Using multiple regression, can we predict bandwidth usage based on other variables in the churn dataset?**

# %%
#data info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CaseOrder             10000 non-null  int64
#  1   Customer_id           10000 non-null  object
#  2   Interaction           10000 non-null  object
#  3   UID                   10000 non-null  object
#  4   City                  10000 non-null  object
#  5   State                 10000 non-null  object
#  6   County                10000 non-null  object
#  7   Zip                   10000 non-null  int64
#  8   Lat                   10000 non-null  float64
#  9   Lng                   10000 non-null  float64
#  10  Population            10000 non-null  int64
#  11  Area                  10000 non-null  object
#  12  TimeZone              10000 non-null  object
#  13  Job                   10000 non-null  object
#  14  Children              10000 non-null  int64
#  15  Age                   10000 non-null  int64
#  16  Income                10000 non-null  float64
#  17  Marital               10000 non-null  object
#  18  Gender                10000 non-null  object
#  19  Churn                 10000 non-null  object
#  20  Outage_sec_perweek    10000 non-null  float64
#  21  Email                 10000 non-null  int64
#  22  Contacts              10000 non-null  int64
#  23  Yearly_equip_failure  10000 non-null  int64
#  24  Techie                10000 non-null  object
#  25  Contract              10000 non-null  object
#  26  Port_modem            10000 non-null  object
#  27  Tablet                10000 non-null  object
#  28  InternetService       10000 non-null  object
#  29  Phone                 10000 non-null  object
#  30  Multiple              10000 non-null  object
#  31  OnlineSecurity        10000 non-null  object
#  32  OnlineBackup          10000 non-null  object
#  33  DeviceProtection      10000 non-null  object
#  34  TechSupport           10000 non-null  object
#  35  StreamingTV           10000 non-null  object
#  36  StreamingMovies       10000 non-null  object
#  37  PaperlessBilling      10000 non-null  object
#  38  PaymentMethod         10000 non-null  object
#  39  Tenure                10000 non-null  float64
#  40  MonthlyCharge         10000 non-null  float64
#  41  Bandwidth_GB_Year     10000 non-null  float64
#  42  Item1                 10000 non-null  int64
#  43  Item2                 10000 non-null  int64
#  44  Item3                 10000 non-null  int64
#  45  Item4                 10000 non-null  int64
#  46  Item5                 10000 non-null  int64
#  47  Item6                 10000 non-null  int64
#  48  Item7                 10000 non-null  int64
#  49  Item8                 10000 non-null  int64
# dtypes: float64(7), int64(16), object(27)
# memory usage: 3.8+ MB

# %%
# Checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().values.any()
# Out:
# False

# %%
#Checking for null
df.isna().sum()
# Out:
# CaseOrder               0
# Customer_id             0
# Interaction             0
# UID                     0
# City                    0
# State                   0
# County                  0
# Zip                     0
# Lat                     0
# Lng                     0
# Population              0
# Area                    0
# TimeZone                0
# Job                     0
# Children                0
# Age                     0
# Income                  0
# Marital                 0
# Gender                  0
# Churn                   0
# Outage_sec_perweek      0
# Email                   0
# Contacts                0
# Yearly_equip_failure    0
# Techie                  0
# Contract                0
# Port_modem              0
# Tablet                  0
# InternetService         0
# Phone                   0
# Multiple                0
# OnlineSecurity          0
# OnlineBackup            0
# DeviceProtection        0
# TechSupport             0
# StreamingTV             0
# StreamingMovies         0
# PaperlessBilling        0
# PaymentMethod           0
# Tenure                  0
# MonthlyCharge           0
# Bandwidth_GB_Year       0
# Item1                   0
# Item2                   0
# Item3                   0
# Item4                   0
# Item5                   0
# Item6                   0
# Item7                   0
# Item8                   0
# dtype: int64

# %%
df.head()
# Out:
#    CaseOrder Customer_id                           Interaction  \
# 0          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# 1          2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# 2          3     K191035  344d114c-3736-4be5-98f7-c72c281e2d35
# 3          4      D90850  abfa2b40-2d43-4994-b15a-989b8c79e311
# 4          5     K662701  68a861fd-0d20-4e51-a587-8a90407ee574
#
#                                 UID         City State                 County  \
# 0  e885b299883d4f9fb18e39c75155d990  Point Baker    AK  Prince of Wales-Hyder
# 1  f2de8bef964785f41a2959829830fb8a  West Branch    MI                 Ogemaw
# 2  f1784cfa9f6d92ae816197eb175d3c71      Yamhill    OR                Yamhill
# 3  dc8a365077241bb5cd5ccd305136b05e      Del Mar    CA              San Diego
# 4  aabb64a116e83fdc4befc1fbab1663f9    Needville    TX              Fort Bend
#
#      Zip       Lat        Lng  Population      Area             TimeZone  \
# 0  99927  56.25100 -133.37571          38     Urban        America/Sitka
# 1  48661  44.32893  -84.24080       10446     Urban      America/Detroit
# 2  97148  45.35589 -123.24657        3735     Urban  America/Los_Angeles
# 3  92014  32.96687 -117.24798       13863  Suburban  America/Los_Angeles
# 4  77461  29.38012  -95.80673       11352  Suburban      America/Chicago
#
#                                  Job  Children  Age    Income    Marital  \
# 0  Environmental health practitioner         0   68  28561.99    Widowed
# 1             Programmer, multimedia         1   27  21704.77    Married
# 2            Chief Financial Officer         4   50   9609.57    Widowed
# 3                          Solicitor         1   48  18925.23    Married
# 4                Medical illustrator         0   83  40074.19  Separated
#
#    Gender Churn  Outage_sec_perweek  Email  Contacts  Yearly_equip_failure  \
# 0    Male    No            7.978323     10         0                     1
# 1  Female   Yes           11.699080     12         0                     1
# 2  Female    No           10.752800      9         0                     1
# 3    Male    No           14.913540     15         2                     0
# 4    Male   Yes            8.147417     16         2                     1
#
#   Techie        Contract Port_modem Tablet InternetService Phone Multiple  \
# 0     No        One year        Yes    Yes     Fiber Optic   Yes       No
# 1    Yes  Month-to-month         No    Yes     Fiber Optic   Yes      Yes
# 2    Yes        Two Year        Yes     No             DSL   Yes      Yes
# 3    Yes        Two Year         No     No             DSL   Yes       No
# 4     No  Month-to-month        Yes     No     Fiber Optic    No       No
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0            Yes          Yes               No          No          No
# 1            Yes           No               No          No         Yes
# 2             No           No               No          No          No
# 3            Yes           No               No          No         Yes
# 4             No           No               No         Yes         Yes
#
#   StreamingMovies PaperlessBilling             PaymentMethod     Tenure  \
# 0             Yes              Yes   Credit Card (automatic)   6.795513
# 1             Yes              Yes  Bank Transfer(automatic)   1.156681
# 2             Yes              Yes   Credit Card (automatic)  15.754144
# 3              No              Yes              Mailed Check  17.087227
# 4              No               No              Mailed Check   1.670972
#
#    MonthlyCharge  Bandwidth_GB_Year  Item1  Item2  Item3  Item4  Item5  Item6  \
# 0     172.455519         904.536110      5      5      5      3      4      4
# 1     242.632554         800.982766      3      4      3      3      4      3
# 2     159.947583        2054.706961      4      4      2      4      4      3
# 3     119.956840        2164.579412      4      4      4      2      5      4
# 4     149.948316         271.493436      4      4      4      3      4      4
#
#    Item7  Item8
# 0      3      4
# 1      4      4
# 2      3      3
# 3      3      3
# 4      4      5

# %% [markdown]
# ### Descriptive statistics

# %%
df.describe(include= 'all').T
# Out:
#                         count unique                                   top  \
# CaseOrder             10000.0    NaN                                   NaN
# Customer_id             10000  10000                               K409198
# Interaction             10000  10000  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# UID                     10000  10000      e885b299883d4f9fb18e39c75155d990
# City                    10000   6058                               Houston
# State                   10000     52                                    TX
# County                  10000   1620                            Washington
# Zip                   10000.0    NaN                                   NaN
# Lat                   10000.0    NaN                                   NaN
# Lng                   10000.0    NaN                                   NaN
# Population            10000.0    NaN                                   NaN
# Area                    10000      3                              Suburban
# TimeZone                10000     25                      America/New_York
# Job                     10000    639             Occupational psychologist
# Children              10000.0    NaN                                   NaN
# Age                   10000.0    NaN                                   NaN
# Income                10000.0    NaN                                   NaN
# Marital                 10000      5                              Divorced
# Gender                  10000      3                                Female
# Churn                   10000      2                                    No
# Outage_sec_perweek    10000.0    NaN                                   NaN
# Email                 10000.0    NaN                                   NaN
# Contacts              10000.0    NaN                                   NaN
# Yearly_equip_failure  10000.0    NaN                                   NaN
# Techie                  10000      2                                    No
# Contract                10000      3                        Month-to-month
# Port_modem              10000      2                                    No
# Tablet                  10000      2                                    No
# InternetService         10000      3                           Fiber Optic
# Phone                   10000      2                                   Yes
# Multiple                10000      2                                    No
# OnlineSecurity          10000      2                                    No
# OnlineBackup            10000      2                                    No
# DeviceProtection        10000      2                                    No
# TechSupport             10000      2                                    No
# StreamingTV             10000      2                                    No
# StreamingMovies         10000      2                                    No
# PaperlessBilling        10000      2                                   Yes
# PaymentMethod           10000      4                      Electronic Check
# Tenure                10000.0    NaN                                   NaN
# MonthlyCharge         10000.0    NaN                                   NaN
# Bandwidth_GB_Year     10000.0    NaN                                   NaN
# Item1                 10000.0    NaN                                   NaN
# Item2                 10000.0    NaN                                   NaN
# Item3                 10000.0    NaN                                   NaN
# Item4                 10000.0    NaN                                   NaN
# Item5                 10000.0    NaN                                   NaN
# Item6                 10000.0    NaN                                   NaN
# Item7                 10000.0    NaN                                   NaN
# Item8                 10000.0    NaN                                   NaN
#
#                       freq          mean           std         min  \
# CaseOrder              NaN        5000.5    2886.89568         1.0
# Customer_id              1           NaN           NaN         NaN
# Interaction              1           NaN           NaN         NaN
# UID                      1           NaN           NaN         NaN
# City                    34           NaN           NaN         NaN
# State                  603           NaN           NaN         NaN
# County                 111           NaN           NaN         NaN
# Zip                    NaN    49153.3196  27532.196108       601.0
# Lat                    NaN     38.757567      5.437389    17.96612
# Lng                    NaN    -90.782536     15.156142  -171.68815
# Population             NaN     9756.5624  14432.698671         0.0
# Area                  3346           NaN           NaN         NaN
# TimeZone              4072           NaN           NaN         NaN
# Job                     30           NaN           NaN         NaN
# Children               NaN        2.0877        2.1472         0.0
# Age                    NaN       53.0784     20.698882        18.0
# Income                 NaN  39806.926771  28199.916702      348.67
# Marital               2092           NaN           NaN         NaN
# Gender                5025           NaN           NaN         NaN
# Churn                 7350           NaN           NaN         NaN
# Outage_sec_perweek     NaN     10.001848      2.976019    0.099747
# Email                  NaN        12.016      3.025898         1.0
# Contacts               NaN        0.9942      0.988466         0.0
# Yearly_equip_failure   NaN         0.398      0.635953         0.0
# Techie                8321           NaN           NaN         NaN
# Contract              5456           NaN           NaN         NaN
# Port_modem            5166           NaN           NaN         NaN
# Tablet                7009           NaN           NaN         NaN
# InternetService       4408           NaN           NaN         NaN
# Phone                 9067           NaN           NaN         NaN
# Multiple              5392           NaN           NaN         NaN
# OnlineSecurity        6424           NaN           NaN         NaN
# OnlineBackup          5494           NaN           NaN         NaN
# DeviceProtection      5614           NaN           NaN         NaN
# TechSupport           6250           NaN           NaN         NaN
# StreamingTV           5071           NaN           NaN         NaN
# StreamingMovies       5110           NaN           NaN         NaN
# PaperlessBilling      5882           NaN           NaN         NaN
# PaymentMethod         3398           NaN           NaN         NaN
# Tenure                 NaN     34.526188     26.443063    1.000259
# MonthlyCharge          NaN    172.624816     42.943094    79.97886
# Bandwidth_GB_Year      NaN    3392.34155   2185.294852  155.506715
# Item1                  NaN        3.4908      1.037797         1.0
# Item2                  NaN        3.5051      1.034641         1.0
# Item3                  NaN         3.487      1.027977         1.0
# Item4                  NaN        3.4975      1.025816         1.0
# Item5                  NaN        3.4929      1.024819         1.0
# Item6                  NaN        3.4973      1.033586         1.0
# Item7                  NaN        3.5095      1.028502         1.0
# Item8                  NaN        3.4956      1.028633         1.0
#
#                               25%          50%         75%         max
# CaseOrder                 2500.75       5000.5     7500.25     10000.0
# Customer_id                   NaN          NaN         NaN         NaN
# Interaction                   NaN          NaN         NaN         NaN
# UID                           NaN          NaN         NaN         NaN
# City                          NaN          NaN         NaN         NaN
# State                         NaN          NaN         NaN         NaN
# County                        NaN          NaN         NaN         NaN
# Zip                       26292.5      48869.5     71866.5     99929.0
# Lat                     35.341828      39.3958   42.106908    70.64066
# Lng                    -97.082812     -87.9188  -80.088745   -65.66785
# Population                  738.0       2910.5     13168.0    111850.0
# Area                          NaN          NaN         NaN         NaN
# TimeZone                      NaN          NaN         NaN         NaN
# Job                           NaN          NaN         NaN         NaN
# Children                      0.0          1.0         3.0        10.0
# Age                          35.0         53.0        71.0        89.0
# Income                 19224.7175    33170.605    53246.17    258900.7
# Marital                       NaN          NaN         NaN         NaN
# Gender                        NaN          NaN         NaN         NaN
# Churn                         NaN          NaN         NaN         NaN
# Outage_sec_perweek       8.018214     10.01856   11.969485    21.20723
# Email                        10.0         12.0        14.0        23.0
# Contacts                      0.0          1.0         2.0         7.0
# Yearly_equip_failure          0.0          0.0         1.0         6.0
# Techie                        NaN          NaN         NaN         NaN
# Contract                      NaN          NaN         NaN         NaN
# Port_modem                    NaN          NaN         NaN         NaN
# Tablet                        NaN          NaN         NaN         NaN
# InternetService               NaN          NaN         NaN         NaN
# Phone                         NaN          NaN         NaN         NaN
# Multiple                      NaN          NaN         NaN         NaN
# OnlineSecurity                NaN          NaN         NaN         NaN
# OnlineBackup                  NaN          NaN         NaN         NaN
# DeviceProtection              NaN          NaN         NaN         NaN
# TechSupport                   NaN          NaN         NaN         NaN
# StreamingTV                   NaN          NaN         NaN         NaN
# StreamingMovies               NaN          NaN         NaN         NaN
# PaperlessBilling              NaN          NaN         NaN         NaN
# PaymentMethod                 NaN          NaN         NaN         NaN
# Tenure                   7.917694    35.430507   61.479795    71.99928
# MonthlyCharge          139.979239     167.4847  200.734725  290.160419
# Bandwidth_GB_Year     1236.470827  3279.536903  5586.14137  7158.98153
# Item1                         3.0          3.0         4.0         7.0
# Item2                         3.0          4.0         4.0         7.0
# Item3                         3.0          3.0         4.0         8.0
# Item4                         3.0          3.0         4.0         7.0
# Item5                         3.0          3.0         4.0         7.0
# Item6                         3.0          3.0         4.0         8.0
# Item7                         3.0          4.0         4.0         7.0
# Item8                         3.0          3.0         4.0         8.0

# %% [markdown]
# ### **Observation for the descriptive statistics**
# - There are 50 columns and 10000 rows in the churn dataset
# - CaseOrder, Customer_id,	Interaction, UID, Zip,	Lat,	Lng, TimeZone	do not provide any added value for our analysis. They mainly serve the prpose of identificatiion and canot be used as  continuous variables
# - City, State, county and Job have unique values of 6058, 52,1620 and 639  respectively. Using them in our analysis will increase the number of columns and create more dimensions in the data set. The population column might not be useful simply b ecause it is hard to associate a population number to a single row that represents only one customer.
# - The above mentioned columns (13 in total) will be dropped bringing the remaining columns to 37.
# - The dataset does not have any null, NaNs or duplicated values
# - After cleaning , we are left with 19 categorical variables in the data set. Dummy variables will be created for these categorical columns as part of the transformation process. 18 numercical variables were left including the target variable Bandwidth_GB_Year. From the the previous project, this column was identified as being a U-shaped distribution.
# - Full statistical analysis of all variables will be discussed in C4 below

# %% [markdown]
# ### **Steps used to Prepare Data.**
# - imported the necessary libraries and defined custom functions for data manipulation
# - identified and dropped unnecessary columns
# - Rename the survey response features (8 columns items total) for better data labeling
# - Observed descriptive statistics of the remaining data frame
# - checked for nulls, duplicates, and other anomalies
# - Extract categorical variables into a list and print summary statistics
# - Performed univariate and bivariate visualizations
# - created dummy variables for categorical data
# - Made a copy of the prepared dataset and save it to csv file

# %% [markdown]
# #### **Dropping unnecessary columns and renaming response columns**

# %%
# Dropping unnecessary columns
cols_to_drop =['CaseOrder', 'Customer_id', 'Interaction', 'UID', 'Zip', 'Lat', 'Lng', 'TimeZone','City', 'State', 'County','Job','Population' ]

# Dropping unnecessary columns
df = df.drop(cols_to_drop, axis = 1)

# renaming the survey items columns
df = df.rename(columns={'Item1': 'TimelyResponse','Item2': 'TimelyFixes' , 'Item3': 'TimelyReplacements', 'Item4': 'Reliability',

                          'Item5': 'Options', 'Item6': 'RespectfulResponse', 'Item7': 'CourteousExchange', 'Item8': 'ActiveListening'})

# Checking to confirm if unnecessary columns were dropped and survey columns renamed appropriately

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Area                  10000 non-null  object
#  1   Children              10000 non-null  int64
#  2   Age                   10000 non-null  int64
#  3   Income                10000 non-null  float64
#  4   Marital               10000 non-null  object
#  5   Gender                10000 non-null  object
#  6   Churn                 10000 non-null  object
#  7   Outage_sec_perweek    10000 non-null  float64
#  8   Email                 10000 non-null  int64
#  9   Contacts              10000 non-null  int64
#  10  Yearly_equip_failure  10000 non-null  int64
#  11  Techie                10000 non-null  object
#  12  Contract              10000 non-null  object
#  13  Port_modem            10000 non-null  object
#  14  Tablet                10000 non-null  object
#  15  InternetService       10000 non-null  object
#  16  Phone                 10000 non-null  object
#  17  Multiple              10000 non-null  object
#  18  OnlineSecurity        10000 non-null  object
#  19  OnlineBackup          10000 non-null  object
#  20  DeviceProtection      10000 non-null  object
#  21  TechSupport           10000 non-null  object
#  22  StreamingTV           10000 non-null  object
#  23  StreamingMovies       10000 non-null  object
#  24  PaperlessBilling      10000 non-null  object
#  25  PaymentMethod         10000 non-null  object
#  26  Tenure                10000 non-null  float64
#  27  MonthlyCharge         10000 non-null  float64
#  28  Bandwidth_GB_Year     10000 non-null  float64
#  29  TimelyResponse        10000 non-null  int64
#  30  TimelyFixes           10000 non-null  int64
#  31  TimelyReplacements    10000 non-null  int64
#  32  Reliability           10000 non-null  int64
#  33  Options               10000 non-null  int64
#  34  RespectfulResponse    10000 non-null  int64
#  35  CourteousExchange     10000 non-null  int64
#  36  ActiveListening       10000 non-null  int64
# dtypes: float64(5), int64(13), object(19)
# memory usage: 2.8+ MB

# %%
df.InternetService.value_counts()
# Out:
# Fiber Optic    4408
# DSL            3463
# None           2129
# Name: InternetService, dtype: int64

# %% [markdown]
# #### **Describtive statistics**

# %%
# Descriptive statistics of numerical variables
df.describe().T
# Out:
#                         count          mean           std         min  \
# Children              10000.0      2.087700      2.147200    0.000000
# Age                   10000.0     53.078400     20.698882   18.000000
# Income                10000.0  39806.926771  28199.916702  348.670000
# Outage_sec_perweek    10000.0     10.001848      2.976019    0.099747
# Email                 10000.0     12.016000      3.025898    1.000000
# Contacts              10000.0      0.994200      0.988466    0.000000
# Yearly_equip_failure  10000.0      0.398000      0.635953    0.000000
# Tenure                10000.0     34.526188     26.443063    1.000259
# MonthlyCharge         10000.0    172.624816     42.943094   79.978860
# Bandwidth_GB_Year     10000.0   3392.341550   2185.294852  155.506715
# TimelyResponse        10000.0      3.490800      1.037797    1.000000
# TimelyFixes           10000.0      3.505100      1.034641    1.000000
# TimelyReplacements    10000.0      3.487000      1.027977    1.000000
# Reliability           10000.0      3.497500      1.025816    1.000000
# Options               10000.0      3.492900      1.024819    1.000000
# RespectfulResponse    10000.0      3.497300      1.033586    1.000000
# CourteousExchange     10000.0      3.509500      1.028502    1.000000
# ActiveListening       10000.0      3.495600      1.028633    1.000000
#
#                                25%           50%           75%            max
# Children                  0.000000      1.000000      3.000000      10.000000
# Age                      35.000000     53.000000     71.000000      89.000000
# Income                19224.717500  33170.605000  53246.170000  258900.700000
# Outage_sec_perweek        8.018214     10.018560     11.969485      21.207230
# Email                    10.000000     12.000000     14.000000      23.000000
# Contacts                  0.000000      1.000000      2.000000       7.000000
# Yearly_equip_failure      0.000000      0.000000      1.000000       6.000000
# Tenure                    7.917694     35.430507     61.479795      71.999280
# MonthlyCharge           139.979239    167.484700    200.734725     290.160419
# Bandwidth_GB_Year      1236.470827   3279.536903   5586.141370    7158.981530
# TimelyResponse            3.000000      3.000000      4.000000       7.000000
# TimelyFixes               3.000000      4.000000      4.000000       7.000000
# TimelyReplacements        3.000000      3.000000      4.000000       8.000000
# Reliability               3.000000      3.000000      4.000000       7.000000
# Options                   3.000000      3.000000      4.000000       7.000000
# RespectfulResponse        3.000000      3.000000      4.000000       8.000000
# CourteousExchange         3.000000      4.000000      4.000000       7.000000
# ActiveListening           3.000000      3.000000      4.000000       8.000000

# %% [markdown]
# #### **Checking for nulls and duplicated values**

# %%
# checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# checking for nulls  / NaNs
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### **Descriptive statistics of categorical columns**

# %%
#extracting categorical variables
cat_vars =  df.select_dtypes(include=['object']).columns.to_list()

 
 #summary statistics of categorical variables
 # Printing number of count of each unique value in each column
for column in cat_vars:
    print(df[column].value_counts())
    print("-" * 40)
# Out:
# Suburban    3346
# Urban       3327
# Rural       3327
# Name: Area, dtype: int64
# ----------------------------------------
# Divorced         2092
# Widowed          2027
# Separated        2014
# Never Married    1956
# Married          1911
# Name: Marital, dtype: int64
# ----------------------------------------
# Female       5025
# Male         4744
# Nonbinary     231
# Name: Gender, dtype: int64
# ----------------------------------------
# No     7350
# Yes    2650
# Name: Churn, dtype: int64
# ----------------------------------------
# No     8321
# Yes    1679
# Name: Techie, dtype: int64
# ----------------------------------------
# Month-to-month    5456
# Two Year          2442
# One year          2102
# Name: Contract, dtype: int64
# ----------------------------------------
# No     5166
# Yes    4834
# Name: Port_modem, dtype: int64
# ----------------------------------------
# No     7009
# Yes    2991
# Name: Tablet, dtype: int64
# ----------------------------------------
# Fiber Optic    4408
# DSL            3463
# None           2129
# Name: InternetService, dtype: int64
# ----------------------------------------
# Yes    9067
# No      933
# Name: Phone, dtype: int64
# ----------------------------------------
# No     5392
# Yes    4608
# Name: Multiple, dtype: int64
# ----------------------------------------
# No     6424
# Yes    3576
# Name: OnlineSecurity, dtype: int64
# ----------------------------------------
# No     5494
# Yes    4506
# Name: OnlineBackup, dtype: int64
# ----------------------------------------
# No     5614
# Yes    4386
# Name: DeviceProtection, dtype: int64
# ----------------------------------------
# No     6250
# Yes    3750
# Name: TechSupport, dtype: int64
# ----------------------------------------
# No     5071
# Yes    4929
# Name: StreamingTV, dtype: int64
# ----------------------------------------
# No     5110
# Yes    4890
# Name: StreamingMovies, dtype: int64
# ----------------------------------------
# Yes    5882
# No     4118
# Name: PaperlessBilling, dtype: int64
# ----------------------------------------
# Electronic Check            3398
# Mailed Check                2290
# Bank Transfer(automatic)    2229
# Credit Card (automatic)     2083
# Name: PaymentMethod, dtype: int64
# ----------------------------------------

# %%
for col in cat_vars:
   df[col] = df[col].astype('category')

# %%
df.Marital = df.Marital.cat.rename_categories({"Divorced":"Divorced","Widowed": "Widowed","Separated": "Separated", "Never Married": "NeverMarried", "Married":"Married"}) 
df.Contract = df.Contract.cat.rename_categories({"Month-to-month":"month_to_month","Two Year": "TwoYear","One year": "OneYear"})
df.InternetService = df.InternetService.cat.rename_categories({"Fiber Optic":"Fiber","DSL": "DSL","None": "NoService"})
df.PaymentMethod = df.PaymentMethod.cat.rename_categories({"Electronic Check":"ElectronicCheck","Mailed Check": "MailedCheck","Bank Transfer(automatic)": "BankTransfer",
                                                           "Credit Card (automatic)": "CreditCard"})

# %%
df.InternetService.value_counts()
# Out:
# Fiber        4408
# DSL          3463
# NoService    2129
# Name: InternetService, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Area                  10000 non-null  category
#  1   Children              10000 non-null  int64
#  2   Age                   10000 non-null  int64
#  3   Income                10000 non-null  float64
#  4   Marital               10000 non-null  category
#  5   Gender                10000 non-null  category
#  6   Churn                 10000 non-null  category
#  7   Outage_sec_perweek    10000 non-null  float64
#  8   Email                 10000 non-null  int64
#  9   Contacts              10000 non-null  int64
#  10  Yearly_equip_failure  10000 non-null  int64
#  11  Techie                10000 non-null  category
#  12  Contract              10000 non-null  category
#  13  Port_modem            10000 non-null  category
#  14  Tablet                10000 non-null  category
#  15  InternetService       10000 non-null  category
#  16  Phone                 10000 non-null  category
#  17  Multiple              10000 non-null  category
#  18  OnlineSecurity        10000 non-null  category
#  19  OnlineBackup          10000 non-null  category
#  20  DeviceProtection      10000 non-null  category
#  21  TechSupport           10000 non-null  category
#  22  StreamingTV           10000 non-null  category
#  23  StreamingMovies       10000 non-null  category
#  24  PaperlessBilling      10000 non-null  category
#  25  PaymentMethod         10000 non-null  category
#  26  Tenure                10000 non-null  float64
#  27  MonthlyCharge         10000 non-null  float64
#  28  Bandwidth_GB_Year     10000 non-null  float64
#  29  TimelyResponse        10000 non-null  int64
#  30  TimelyFixes           10000 non-null  int64
#  31  TimelyReplacements    10000 non-null  int64
#  32  Reliability           10000 non-null  int64
#  33  Options               10000 non-null  int64
#  34  RespectfulResponse    10000 non-null  int64
#  35  CourteousExchange     10000 non-null  int64
#  36  ActiveListening       10000 non-null  int64
# dtypes: category(19), float64(5), int64(13)
# memory usage: 1.6 MB

# %% [markdown]
# ### **Univariate and bivariate visualizations**
# #### **Univariate visualization Categorical variables**

# %%
for x in cat_vars:
  labeled_barplot(df, x, perc=True)
  print('*'*45)
# Out:
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************
# *********************************************

# %% [markdown]
# #### **Univariate visualization continuous variables**

# %%
for x in df.columns.to_list():
  if x not in cat_vars:
    histogram_boxplot(df, x)

# %% [markdown]
# ##**Bivariate Visualization**
#
# ###**Heat map ( continuous variables)**

# %%
# lets perform correlation
plt.figure(figsize= (15, 6))
correlation = df.corr()
sns.heatmap(correlation, annot= True,vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.title("Correlation Matrix")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.TimelyResponse,df.Bandwidth_GB_Year,palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.TimelyFixes,df.Bandwidth_GB_Year,palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.TimelyReplacements,df.Bandwidth_GB_Year,palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.Reliability,df.Bandwidth_GB_Year,palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.Options,df.Bandwidth_GB_Year,palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.RespectfulResponse,df.Bandwidth_GB_Year,palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.CourteousExchange,df.Bandwidth_GB_Year,palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.ActiveListening,df.Bandwidth_GB_Year,palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(df.MonthlyCharge,df.Bandwidth_GB_Year, ci=0)
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(df.Age,df.Bandwidth_GB_Year, ci=0)
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(df.Income,df.Bandwidth_GB_Year,ci=0)
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(df.Tenure, df.Bandwidth_GB_Year,ci=0)
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(df.Outage_sec_perweek,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.Children,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.Contacts,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.Email,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.lineplot(df.Yearly_equip_failure,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.Gender,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.Area,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.Bandwidth_GB_Year,df.Marital,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.Contract,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.InternetService,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.Bandwidth_GB_Year,df.PaymentMethod,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.OnlineSecurity,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.Techie,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.Port_modem,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.Tablet,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.Phone,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.Multiple,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.OnlineBackup,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.DeviceProtection,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.TechSupport,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.StreamingMovies,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.StreamingTV,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.PaperlessBilling,df.Bandwidth_GB_Year,palette="viridis")
plt.show()

# %%
cols_totreat =['Children','Income','Outage_sec_perweek','Email','Contacts','Yearly_equip_failure',
               'TimelyResponse','TimelyFixes','TimelyReplacements','Reliability','Options',
               'RespectfulResponse','CourteousExchange','ActiveListening']

# %%
#Getting dummy variables for categorical columns
df = pd.get_dummies(df, drop_first=True)

#making a copy of the prepared dataset and extract a copy for submission

churn_df =  df.copy()

# %%
churn_df.to_csv('prepared_churn.csv')

# %%
def Generate_heatmap_graph(corr, chart_title, mask_uppertri=False ):
    """ Based on features , generate correlation matrix """
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = mask_uppertri
    fig,ax = plt.subplots(figsize=(20,10))
    sns.heatmap(corr
                , mask = mask
                , square = True
                , annot = True
                , annot_kws={'size': 10.5, 'weight' : 'bold'}
                , cmap=plt.get_cmap("YlOrBr")
                , linewidths=.1)
    plt.title(chart_title, fontsize=14)
    plt.show()
var_corr = round(churn_df.corr(),2)
Generate_heatmap_graph(var_corr
                       ,chart_title = 'Correlation Heatmap'
                       ,mask_uppertri = True)

# %%
churn = df.copy()

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Children                       10000 non-null  int64
#  1   Age                            10000 non-null  int64
#  2   Income                         10000 non-null  float64
#  3   Outage_sec_perweek             10000 non-null  float64
#  4   Email                          10000 non-null  int64
#  5   Contacts                       10000 non-null  int64
#  6   Yearly_equip_failure           10000 non-null  int64
#  7   Tenure                         10000 non-null  float64
#  8   MonthlyCharge                  10000 non-null  float64
#  9   Bandwidth_GB_Year              10000 non-null  float64
#  10  TimelyResponse                 10000 non-null  int64
#  11  TimelyFixes                    10000 non-null  int64
#  12  TimelyReplacements             10000 non-null  int64
#  13  Reliability                    10000 non-null  int64
#  14  Options                        10000 non-null  int64
#  15  RespectfulResponse             10000 non-null  int64
#  16  CourteousExchange              10000 non-null  int64
#  17  ActiveListening                10000 non-null  int64
#  18  Area_Suburban                  10000 non-null  uint8
#  19  Area_Urban                     10000 non-null  uint8
#  20  Marital_Married                10000 non-null  uint8
#  21  Marital_NeverMarried           10000 non-null  uint8
#  22  Marital_Separated              10000 non-null  uint8
#  23  Marital_Widowed                10000 non-null  uint8
#  24  Gender_Male                    10000 non-null  uint8
#  25  Gender_Nonbinary               10000 non-null  uint8
#  26  Churn_Yes                      10000 non-null  uint8
#  27  Techie_Yes                     10000 non-null  uint8
#  28  Contract_OneYear               10000 non-null  uint8
#  29  Contract_TwoYear               10000 non-null  uint8
#  30  Port_modem_Yes                 10000 non-null  uint8
#  31  Tablet_Yes                     10000 non-null  uint8
#  32  InternetService_Fiber          10000 non-null  uint8
#  33  InternetService_NoService      10000 non-null  uint8
#  34  Phone_Yes                      10000 non-null  uint8
#  35  Multiple_Yes                   10000 non-null  uint8
#  36  OnlineSecurity_Yes             10000 non-null  uint8
#  37  OnlineBackup_Yes               10000 non-null  uint8
#  38  DeviceProtection_Yes           10000 non-null  uint8
#  39  TechSupport_Yes                10000 non-null  uint8
#  40  StreamingTV_Yes                10000 non-null  uint8
#  41  StreamingMovies_Yes            10000 non-null  uint8
#  42  PaperlessBilling_Yes           10000 non-null  uint8
#  43  PaymentMethod_CreditCard       10000 non-null  uint8
#  44  PaymentMethod_ElectronicCheck  10000 non-null  uint8
#  45  PaymentMethod_MailedCheck      10000 non-null  uint8
# dtypes: float64(5), int64(13), uint8(28)
# memory usage: 1.6 MB

# %% [markdown]
# # **Model  Comparsion and analysis**
# ## **Model ONE All features**

# %%
X = churn_df.drop(["Bandwidth_GB_Year"], axis=1)
y = churn_df["Bandwidth_GB_Year"]

# %%
# creating and fitting initial multiple regression model
      
 
#printing model summary
 
mlr1 = smf.ols(formula=" Bandwidth_GB_Year ~ Children + Age + Income + Tenure + Outage_sec_perweek + Email+ Contacts + Yearly_equip_failure   + MonthlyCharge +TimelyResponse +\
                    TimelyFixes + TimelyReplacements + Reliability + Options + RespectfulResponse + CourteousExchange +ActiveListening + Area_Suburban +\
                    Area_Urban + Marital_Married + Marital_NeverMarried + Marital_Separated +Marital_Widowed + Gender_Male + Gender_Nonbinary +\
                      Churn_Yes + Techie_Yes + Contract_OneYear + Contract_TwoYear + Port_modem_Yes + Tablet_Yes + InternetService_Fiber +\
                      InternetService_NoService + Phone_Yes + Multiple_Yes + OnlineSecurity_Yes + OnlineBackup_Yes + DeviceProtection_Yes +\
                      TechSupport_Yes + StreamingTV_Yes + StreamingMovies_Yes + PaperlessBilling_Yes +PaymentMethod_CreditCard + PaymentMethod_ElectronicCheck +\
                      PaymentMethod_MailedCheck", data=churn_df).fit()
y_hat = mlr1.predict()
print(mlr1.summary2())
# Out:
#                            Results: Ordinary least squares
# ======================================================================================
# Model:                    OLS                     Adj. R-squared:           1.000
# Dependent Variable:       Bandwidth_GB_Year       AIC:                      71930.4731
# Date:                     2022-09-12 13:38        BIC:                      72262.1487
# No. Observations:         10000                   Log-Likelihood:           -35919.
# Df Model:                 45                      F-statistic:              1.369e+07
# Df Residuals:             9954                    Prob (F-statistic):       0.00
# R-squared:                1.000                   Scale:                    77.523
# --------------------------------------------------------------------------------------
#                                 Coef.   Std.Err.     t      P>|t|    [0.025    0.975]
# --------------------------------------------------------------------------------------
# Intercept                      314.9740   1.3592   231.7324 0.0000  312.3096  317.6383
# Children                        30.7695   0.0411   748.8626 0.0000   30.6890   30.8500
# Age                             -3.2762   0.0043  -768.2386 0.0000   -3.2846   -3.2678
# Income                          -0.0000   0.0000    -0.4153 0.6780   -0.0000    0.0000
# Tenure                          81.9324   0.0040 20359.5301 0.0000   81.9245   81.9402
# Outage_sec_perweek              -0.0238   0.0297    -0.8030 0.4220   -0.0820    0.0343
# Email                            0.0059   0.0292     0.2026 0.8394   -0.0513    0.0631
# Contacts                         0.0494   0.0893     0.5531 0.5802   -0.1256    0.2244
# Yearly_equip_failure            -0.0160   0.1388    -0.1156 0.9080   -0.2881    0.2560
# MonthlyCharge                    2.8853   0.0101   285.2753 0.0000    2.8655    2.9051
# TimelyResponse                  -0.1903   0.1264    -1.5054 0.1323   -0.4380    0.0575
# TimelyFixes                      0.0567   0.1184     0.4786 0.6323   -0.1755    0.2888
# TimelyReplacements              -0.0817   0.1086    -0.7517 0.4522   -0.2946    0.1313
# Reliability                     -0.0375   0.0971    -0.3859 0.6996   -0.2278    0.1529
# Options                          0.0498   0.1008     0.4945 0.6210   -0.1478    0.2475
# RespectfulResponse               0.1052   0.1038     1.0135 0.3109   -0.0983    0.3086
# CourteousExchange                0.0871   0.0982     0.8867 0.3753   -0.1054    0.2795
# ActiveListening                 -0.0061   0.0935    -0.0649 0.9482   -0.1893    0.1771
# Area_Suburban                    0.5595   0.2158     2.5930 0.0095    0.1365    0.9825
# Area_Urban                       0.2682   0.2163     1.2402 0.2149   -0.1557    0.6921
# Marital_Married                  0.0479   0.2791     0.1715 0.8639   -0.4993    0.5950
# Marital_NeverMarried             0.0956   0.2775     0.3443 0.7306   -0.4484    0.6395
# Marital_Separated               -0.2156   0.2753    -0.7830 0.4337   -0.7552    0.3241
# Marital_Widowed                 -0.0012   0.2753    -0.0043 0.9965   -0.5408    0.5384
# Gender_Male                     64.9203   0.1788   362.9983 0.0000   64.5698   65.2709
# Gender_Nonbinary               -21.4617   0.5935   -36.1608 0.0000  -22.6251  -20.2983
# Churn_Yes                       -0.2381   0.2797    -0.8513 0.3946   -0.7865    0.3102
# Techie_Yes                       0.0028   0.2368     0.0119 0.9905   -0.4614    0.4670
# Contract_OneYear                -0.1115   0.2359    -0.4728 0.6364   -0.5739    0.3509
# Contract_TwoYear                -0.2058   0.2249    -0.9149 0.3602   -0.6467    0.2351
# Port_modem_Yes                  -0.2171   0.1764    -1.2310 0.2183   -0.5629    0.1286
# Tablet_Yes                      -0.0536   0.1929    -0.2777 0.7813   -0.4317    0.3245
# InternetService_Fiber         -471.4850   0.2871 -1642.4910 0.0000 -472.0477 -470.9223
# InternetService_NoService     -376.9501   0.2753 -1369.4033 0.0000 -377.4897 -376.4105
# Phone_Yes                       -0.1375   0.3036    -0.4528 0.6507   -0.7327    0.4577
# Multiple_Yes                   -21.9984   0.3720   -59.1351 0.0000  -22.7276  -21.2692
# OnlineSecurity_Yes              68.1087   0.1862   365.7754 0.0000   67.7437   68.4737
# OnlineBackup_Yes                29.0989   0.2878   101.1081 0.0000   28.5348   29.6631
# DeviceProtection_Yes            48.9149   0.2178   224.5814 0.0000   48.4880   49.3419
# TechSupport_Yes                -31.5526   0.2218  -142.2430 0.0000  -31.9874  -31.1178
# StreamingTV_Yes                106.3859   0.4585   232.0501 0.0000  105.4872  107.2846
# StreamingMovies_Yes             59.2107   0.5537   106.9423 0.0000   58.1254   60.2961
# PaperlessBilling_Yes             0.3028   0.1793     1.6882 0.0914   -0.0488    0.6543
# PaymentMethod_CreditCard        -0.1632   0.2688    -0.6070 0.5438   -0.6901    0.3637
# PaymentMethod_ElectronicCheck   -0.2324   0.2406    -0.9656 0.3343   -0.7041    0.2393
# PaymentMethod_MailedCheck       -0.5954   0.2626    -2.2674 0.0234   -1.1102   -0.0807
# --------------------------------------------------------------------------------------
# Omnibus:                    34822.401            Durbin-Watson:               2.002
# Prob(Omnibus):              0.000                Jarque-Bera (JB):            1633.272
# Skew:                       0.034                Prob(JB):                    0.000
# Kurtosis:                   1.021                Condition No.:               817164
# ======================================================================================
# * The condition number is large (8e+05). This might indicate             strong
# multicollinearity or other numerical problems.

# %%
pd.DataFrame({'Actual': y, 'Predicted': y_hat}).head()
# Out:
#         Actual    Predicted
# 0   904.536110   895.775078
# 1   800.982766   792.422293
# 2  2054.706961  2063.252675
# 3  2164.579412  2173.767584
# 4   271.493436   280.059291

# %%
#Lets visualize the mulile linear regression
plt.figure(figsize= (18, 7))
sns.kdeplot(data= X , x = y)
sns.kdeplot(data= X , x = y_hat)
plt.title('Actual Vs Predicted Bandwidth', size = 15)
plt.show()

# %%
# Performance
print('Root Mean Squared Error = ', mean_squared_error(y, y_hat, squared=False))
print('Mean Absolute Error = ', mean_absolute_error(y, y_hat))
print('R-Squarred = ', r2_score(y, y_hat))
# Out:
# Root Mean Squared Error =  8.784467634649575
# Mean Absolute Error =  8.760964806357753
# R-Squarred =  0.9999838395205887

# %%
# creating and fitting initial multiple regression model
      
 
#printing model summary
 
mlr1 = smf.ols(formula=" Bandwidth_GB_Year ~ Children + Age + Income  + Outage_sec_perweek + Email+ Contacts + Yearly_equip_failure   + MonthlyCharge +TimelyResponse +\
                    TimelyFixes + TimelyReplacements + Reliability + Options + RespectfulResponse + CourteousExchange +ActiveListening + Area_Suburban +\
                    Area_Urban + Marital_Married + Marital_NeverMarried + Marital_Separated +Marital_Widowed + Gender_Male + Gender_Nonbinary +\
                      Churn_Yes + Techie_Yes + Contract_OneYear + Contract_TwoYear + Port_modem_Yes + Tablet_Yes + InternetService_Fiber +\
                      InternetService_NoService + Phone_Yes + Multiple_Yes + OnlineSecurity_Yes + OnlineBackup_Yes + DeviceProtection_Yes +\
                      TechSupport_Yes + StreamingTV_Yes + StreamingMovies_Yes + PaperlessBilling_Yes +PaymentMethod_CreditCard + PaymentMethod_ElectronicCheck +\
                      PaymentMethod_MailedCheck", data=churn_df).fit()
y_hat = mlr1.predict()
print(mlr1.summary2())
# Out:
#                             Results: Ordinary least squares
# =======================================================================================
# Model:                    OLS                     Adj. R-squared:           0.324
# Dependent Variable:       Bandwidth_GB_Year       AIC:                      178297.5034
# Date:                     2022-09-12 13:41        BIC:                      178621.9687
# No. Observations:         10000                   Log-Likelihood:           -89104.
# Df Model:                 44                      F-statistic:              109.9
# Df Residuals:             9955                    Prob (F-statistic):       0.00
# R-squared:                0.327                   Scale:                    3.2280e+06
# ---------------------------------------------------------------------------------------
#                                 Coef.    Std.Err.    t     P>|t|    [0.025     0.975]
# ---------------------------------------------------------------------------------------
# Intercept                      2098.0076 276.7814   7.5800 0.0000  1555.4601  2640.5551
# Children                         29.6287   8.3844   3.5338 0.0004    13.1936    46.0637
# Age                              -1.4241   0.8700  -1.6369 0.1017    -3.1295     0.2813
# Income                            0.0003   0.0006   0.5356 0.5922    -0.0009     0.0016
# Outage_sec_perweek               -0.0573   6.0528  -0.0095 0.9924   -11.9221    11.8075
# Email                            -6.0450   5.9501  -1.0160 0.3097   -17.7083     5.6184
# Contacts                         16.1039  18.2147   0.8841 0.3767   -19.6006    51.8085
# Yearly_equip_failure             11.4856  28.3163   0.4056 0.6850   -44.0201    66.9912
# MonthlyCharge                    17.1414   2.0589   8.3255 0.0000    13.1055    21.1772
# TimelyResponse                  -25.9351  25.7882  -1.0057 0.3146   -76.4851    24.6149
# TimelyFixes                      -2.0400  24.1646  -0.0844 0.9327   -49.4075    45.3275
# TimelyReplacements               16.8691  22.1678   0.7610 0.4467   -26.5843    60.3225
# Reliability                      -5.8340  19.8161  -0.2944 0.7685   -44.6777    33.0096
# Options                          34.6101  20.5677   1.6827 0.0925    -5.7067    74.9269
# RespectfulResponse                3.6908  21.1789   0.1743 0.8617   -37.8242    45.2057
# CourteousExchange                15.2171  20.0327   0.7596 0.4475   -24.0510    54.4852
# ActiveListening                 -26.8820  19.0679  -1.4098 0.1586   -64.2589    10.4950
# Area_Suburban                   -63.9736  44.0274  -1.4530 0.1462  -150.2761    22.3290
# Area_Urban                      -45.7122  44.1261  -1.0359 0.3003  -132.2082    40.7839
# Marital_Married                  57.5155  56.9559   1.0098 0.3126   -54.1295   169.1605
# Marital_NeverMarried             40.9604  56.6219   0.7234 0.4694   -70.0299   151.9507
# Marital_Separated               102.1519  56.1680   1.8187 0.0690    -7.9488   212.2526
# Marital_Widowed                 101.7214  56.1631   1.8112 0.0701    -8.3697   211.8124
# Gender_Male                      74.1774  36.4945   2.0326 0.0421     2.6408   145.7140
# Gender_Nonbinary               -197.1203 121.0967  -1.6278 0.1036  -434.4943    40.2538
# Churn_Yes                     -3181.6512  47.3457 -67.2004 0.0000 -3274.4584 -3088.8440
# Techie_Yes                      182.1627  48.2882   3.7724 0.0002    87.5080   276.8174
# Contract_OneYear               -750.9708  47.5417 -15.7960 0.0000  -844.1621  -657.7795
# Contract_TwoYear               -694.7737  45.3674 -15.3144 0.0000  -783.7029  -605.8444
# Port_modem_Yes                   58.4884  35.9886   1.6252 0.1042   -12.0566   129.0334
# Tablet_Yes                      -16.3953  39.3593  -0.4166 0.6770   -93.5475    60.7569
# InternetService_Fiber         -1076.1616  58.2613 -18.4713 0.0000 -1190.3655  -961.9577
# InternetService_NoService      -548.2858  56.1438  -9.7657 0.0000  -658.3390  -438.2326
# Phone_Yes                       -64.7845  61.9567  -1.0456 0.2958  -186.2322    56.6632
# Multiple_Yes                   -150.7409  75.8988  -1.9861 0.0471  -299.5180    -1.9639
# OnlineSecurity_Yes                1.7974  37.9904   0.0473 0.9623   -72.6715    76.2662
# OnlineBackup_Yes                -60.0149  58.7210  -1.0220 0.3068  -175.1200    55.0901
# DeviceProtection_Yes           -113.9462  44.4147  -2.5655 0.0103  -201.0080   -26.8844
# TechSupport_Yes                -153.8449  45.2478  -3.4001 0.0007  -242.5396   -65.1501
# StreamingTV_Yes                 188.1475  93.5488   2.0112 0.0443     4.7730   371.5221
# StreamingMovies_Yes             113.1205 112.9792   1.0013 0.3167  -108.3416   334.5826
# PaperlessBilling_Yes             32.9394  36.5961   0.9001 0.3681   -38.7963   104.6751
# PaymentMethod_CreditCard        126.0794  54.8387   2.2991 0.0215    18.5845   233.5743
# PaymentMethod_ElectronicCheck   152.0244  49.0816   3.0974 0.0020    55.8144   248.2343
# PaymentMethod_MailedCheck       107.4150  53.5758   2.0049 0.0450     2.3955   212.4345
# ---------------------------------------------------------------------------------------
# Omnibus:                     1776.631             Durbin-Watson:                0.744
# Prob(Omnibus):               0.000                Jarque-Bera (JB):             432.502
# Skew:                        -0.190               Prob(JB):                     0.000
# Kurtosis:                    2.054                Condition No.:                816100
# =======================================================================================
# * The condition number is large (8e+05). This might indicate             strong
# multicollinearity or other numerical problems.

# %%
#Lets visualize the mulile linear regression
plt.figure(figsize= (18, 7))
sns.kdeplot(data= churn_df , x = y, Label='Actual')
sns.kdeplot(data= churn_df , x = y_hat, Label = 'Predicted')
plt.title('Actual Vs Predicted Bandwidth', size = 15)
plt.show()

# %% [markdown]
# # **Model  Comparsion and analysis**
# ## **Model 2 Reduced features**

# %%
# drop all columns from model where p-value > 0.05 (see Geeks for Geeks (2021))
equation = mlr1.summary2().tables[1]
temp_drop = []
for i in equation.itertuples():
    if i[4] > 0.05:
        temp_drop.append(i[0])
        print(f'Drop {i[0]} with p-value of {i[4]:.3f}')
X = pd.DataFrame(X) # reset dataframe
X.drop(temp_drop, axis = 1, inplace=True) # drop
# Out:
# Drop Age with p-value of 0.102
# Drop Income with p-value of 0.592
# Drop Outage_sec_perweek with p-value of 0.992
# Drop Email with p-value of 0.310
# Drop Contacts with p-value of 0.377
# Drop Yearly_equip_failure with p-value of 0.685
# Drop TimelyResponse with p-value of 0.315
# Drop TimelyFixes with p-value of 0.933
# Drop TimelyReplacements with p-value of 0.447
# Drop Reliability with p-value of 0.768
# Drop Options with p-value of 0.092
# Drop RespectfulResponse with p-value of 0.862
# Drop CourteousExchange with p-value of 0.448
# Drop ActiveListening with p-value of 0.159
# Drop Area_Suburban with p-value of 0.146
# Drop Area_Urban with p-value of 0.300
# Drop Marital_Married with p-value of 0.313
# Drop Marital_NeverMarried with p-value of 0.469
# Drop Marital_Separated with p-value of 0.069
# Drop Marital_Widowed with p-value of 0.070
# Drop Gender_Nonbinary with p-value of 0.104
# Drop Port_modem_Yes with p-value of 0.104
# Drop Tablet_Yes with p-value of 0.677
# Drop Phone_Yes with p-value of 0.296
# Drop OnlineSecurity_Yes with p-value of 0.962
# Drop OnlineBackup_Yes with p-value of 0.307
# Drop StreamingMovies_Yes with p-value of 0.317
# Drop PaperlessBilling_Yes with p-value of 0.368

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Children                       10000 non-null  int64
#  1   Tenure                         10000 non-null  float64
#  2   MonthlyCharge                  10000 non-null  float64
#  3   Gender_Male                    10000 non-null  uint8
#  4   Churn_Yes                      10000 non-null  uint8
#  5   Techie_Yes                     10000 non-null  uint8
#  6   Contract_OneYear               10000 non-null  uint8
#  7   Contract_TwoYear               10000 non-null  uint8
#  8   InternetService_Fiber          10000 non-null  uint8
#  9   InternetService_NoService      10000 non-null  uint8
#  10  Multiple_Yes                   10000 non-null  uint8
#  11  DeviceProtection_Yes           10000 non-null  uint8
#  12  TechSupport_Yes                10000 non-null  uint8
#  13  StreamingTV_Yes                10000 non-null  uint8
#  14  PaymentMethod_CreditCard       10000 non-null  uint8
#  15  PaymentMethod_ElectronicCheck  10000 non-null  uint8
#  16  PaymentMethod_MailedCheck      10000 non-null  uint8
# dtypes: float64(2), int64(1), uint8(14)
# memory usage: 371.2 KB

# %% [markdown]
# ### Trying Tenure alone

# %%
mlr2 = smf.ols(formula=" Bandwidth_GB_Year ~  Tenure ", data=churn_df).fit()
 
print(mlr2.summary())
y_hat = mlr2.predict()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Bandwidth_GB_Year   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                 5.803e+05
# Date:                Mon, 12 Sep 2022   Prob (F-statistic):               0.00
# Time:                        13:43:56   Log-Likelihood:                -70693.
# No. Observations:               10000   AIC:                         1.414e+05
# Df Residuals:                    9998   BIC:                         1.414e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    563.3117      4.678    120.424      0.000     554.142     572.481
# Tenure        81.9387      0.108    761.773      0.000      81.728      82.150
# ==============================================================================
# Omnibus:                      317.001   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              261.023
# Skew:                           0.322   Prob(JB):                     2.09e-57
# Kurtosis:                       2.540   Cond. No.                         71.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Lets visualize the mulile linear regression
plt.figure(figsize= (18, 7))
sns.kdeplot(data= churn_df , x = y)
sns.kdeplot(data= churn_df , x = y_hat)
plt.title('Actual Vs Predicted Bandwidth', size = 15)
plt.show()

# %% [markdown]
# ### Model with reduced features

# %%
model2 = smf.ols(formula=" Bandwidth_GB_Year ~ Children + Age +  Tenure  + MonthlyCharge + Area_Suburban +\
                     Gender_Male + Gender_Nonbinary + InternetService_Fiber +\
                      InternetService_NoService + Multiple_Yes + OnlineSecurity_Yes + OnlineBackup_Yes + DeviceProtection_Yes +\
                      TechSupport_Yes + StreamingTV_Yes + StreamingMovies_Yes +\
                      PaymentMethod_MailedCheck", data=churn_df).fit()
 
print(model2.summary2())
# Out:
#                          Results: Ordinary least squares
# ==================================================================================
# Model:                    OLS                   Adj. R-squared:         1.000
# Dependent Variable:       Bandwidth_GB_Year     AIC:                    71891.1473
# Date:                     2022-09-12 13:45      BIC:                    72020.9335
# No. Observations:         10000                 Log-Likelihood:         -35928.
# Df Model:                 17                    F-statistic:            3.627e+07
# Df Residuals:             9982                  Prob (F-statistic):     0.00
# R-squared:                1.000                 Scale:                  77.435
# ----------------------------------------------------------------------------------
#                             Coef.   Std.Err.     t      P>|t|    [0.025    0.975]
# ----------------------------------------------------------------------------------
# Intercept                  314.5797   0.9255   339.9184 0.0000  312.7656  316.3938
# Children                    30.7668   0.0410   750.0739 0.0000   30.6864   30.8472
# Age                         -3.2759   0.0043  -769.4134 0.0000   -3.2842   -3.2676
# Tenure                      81.9341   0.0033 24592.3611 0.0000   81.9276   81.9407
# MonthlyCharge                2.8846   0.0100   288.0848 0.0000    2.8649    2.9042
# Area_Suburban                0.4272   0.1866     2.2893 0.0221    0.0614    0.7929
# Gender_Male                 64.9165   0.1783   364.0235 0.0000   64.5669   65.2661
# Gender_Nonbinary           -21.4721   0.5927   -36.2254 0.0000  -22.6340  -20.3103
# InternetService_Fiber     -471.4539   0.2818 -1672.9315 0.0000 -472.0063 -470.9015
# InternetService_NoService -376.9495   0.2747 -1372.3983 0.0000 -377.4879 -376.4111
# Multiple_Yes               -22.0087   0.3711   -59.2986 0.0000  -22.7362  -21.2811
# OnlineSecurity_Yes          68.1031   0.1857   366.7788 0.0000   67.7391   68.4671
# OnlineBackup_Yes            29.1181   0.2871   101.4327 0.0000   28.5553   29.6808
# DeviceProtection_Yes        48.9200   0.2174   225.0735 0.0000   48.4940   49.3461
# TechSupport_Yes            -31.5523   0.2212  -142.6539 0.0000  -31.9859  -31.1188
# StreamingTV_Yes            106.3544   0.4577   232.3869 0.0000  105.4572  107.2515
# StreamingMovies_Yes         59.1862   0.5527   107.0920 0.0000   58.1028   60.2695
# PaymentMethod_MailedCheck   -0.4530   0.2095    -2.1616 0.0307   -0.8637   -0.0422
# ----------------------------------------------------------------------------------
# Omnibus:                  34688.985           Durbin-Watson:              2.003
# Prob(Omnibus):            0.000               Jarque-Bera (JB):           1644.232
# Skew:                     0.034               Prob(JB):                   0.000
# Kurtosis:                 1.015               Condition No.:              2593
# ==================================================================================
# * The condition number is large (3e+03). This might indicate             strong
# multicollinearity or other numerical problems.

# %%
y_hat = model2.predict(churn_df)

pd.DataFrame({'Actual': y, 'Predicted': y_hat}).head()

# Performance
print('Root Mean Squared Error = ', mean_squared_error(y, y_hat, squared=False))
print('Mean Absolute Error = ', mean_absolute_error(y, y_hat))
print('R-Squarred = ', r2_score(y, y_hat))
# Out:
# Root Mean Squared Error =  8.791794409845764
# Mean Absolute Error =  8.775585283586135
# R-Squarred =  0.9999838125517199

# %%
model2.params
# Out:
# Intercept                    314.579718
# Children                      30.766759
# Age                           -3.275901
# Tenure                        81.934125
# MonthlyCharge                  2.884553
# Area_Suburban                  0.427162
# Gender_Male                   64.916502
# Gender_Nonbinary             -21.472139
# InternetService_Fiber       -471.453908
# InternetService_NoService   -376.949479
# Multiple_Yes                 -22.008652
# OnlineSecurity_Yes            68.103096
# OnlineBackup_Yes              29.118061
# DeviceProtection_Yes          48.920012
# TechSupport_Yes              -31.552314
# StreamingTV_Yes              106.354352
# StreamingMovies_Yes           59.186185
# PaymentMethod_MailedCheck     -0.452954
# dtype: float64

# %% [markdown]
# ## Dropping columns to improve our model

# %%
model3 = smf.ols(formula=" Bandwidth_GB_Year ~ Children +  Tenure  + Gender_Male  +\
                      Multiple_Yes + OnlineSecurity_Yes + OnlineBackup_Yes + DeviceProtection_Yes + StreamingTV_Yes ", data=churn_df).fit()
 
print(model3.summary2())
# Out:
#                     Results: Ordinary least squares
# ========================================================================
# Model:               OLS                Adj. R-squared:      0.988
# Dependent Variable:  Bandwidth_GB_Year  AIC:                 137573.6668
# Date:                2022-09-12 13:46   BIC:                 137638.5599
# No. Observations:    10000              Log-Likelihood:      -68778.
# Df Model:            8                  F-statistic:         1.069e+05
# Df Residuals:        9991               Prob (F-statistic):  0.00
# R-squared:           0.988              Scale:               55193.
# ------------------------------------------------------------------------
#                       Coef.   Std.Err.    t     P>|t|   [0.025   0.975]
# ------------------------------------------------------------------------
# Intercept            207.3464   6.8613  30.2197 0.0000 193.8969 220.7960
# Children              31.6433   1.0945  28.9100 0.0000  29.4978  33.7888
# Tenure                81.9748   0.0889 921.9459 0.0000  81.8005  82.1491
# Gender_Male           70.8350   4.7073  15.0481 0.0000  61.6078  80.0622
# Multiple_Yes          77.7661   4.7146  16.4947 0.0000  68.5245  87.0077
# OnlineSecurity_Yes    80.0050   4.9031  16.3174 0.0000  70.3940  89.6160
# OnlineBackup_Yes      93.7617   4.7236  19.8496 0.0000  84.5024 103.0209
# DeviceProtection_Yes  83.2864   4.7379  17.5788 0.0000  73.9992  92.5736
# StreamingTV_Yes      226.8814   4.7000  48.2729 0.0000 217.6685 236.0943
# ------------------------------------------------------------------------
# Omnibus:                1522.025        Durbin-Watson:           1.966
# Prob(Omnibus):          0.000           Jarque-Bera (JB):        565.762
# Skew:                   0.376           Prob(JB):                0.000
# Kurtosis:               2.110           Condition No.:           146
# ========================================================================

# %%
y_hat = model3.predict(churn_df)

pd.DataFrame({'Actual': y, 'Predicted': y_hat}).head()

# Performance
print('Root Mean Squared Error = ', mean_squared_error(y, y_hat, squared=False))
print('Mean Absolute Error = ', mean_absolute_error(y, y_hat))
print('R-Squarred = ', r2_score(y, y_hat))
# Out:
# Root Mean Squared Error =  234.82599813738605
# Mean Absolute Error =  198.0140076847467
# R-Squarred =  0.9884517626817787

# %%
model3.params
# Out:
# Intercept               207.346447
# Children                 31.643298
# Tenure                   81.974778
# Gender_Male              70.834998
# Multiple_Yes             77.766088
# OnlineSecurity_Yes       80.004977
# OnlineBackup_Yes         93.761661
# DeviceProtection_Yes     83.286405
# StreamingTV_Yes         226.881404
# dtype: float64

# %%
#create residual plots for all of the model's final predictor variables
for c in churn_df[['Children', 'Tenure' ,'Gender_Male','Multiple_Yes', 'OnlineSecurity_Yes',
                   'OnlineBackup_Yes','DeviceProtection_Yes','StreamingTV_Yes']].columns:
                   fig = plt.figure(figsize=(12,8))
                   fig = sm.graphics.plot_regress_exog(model3, c, fig=fig)

# %%
df3= churn_df[['Children', 'Tenure' ,'Gender_Male','Multiple_Yes', 'OnlineSecurity_Yes',
                   'OnlineBackup_Yes','DeviceProtection_Yes','StreamingTV_Yes']].copy()

# %%
# Let us write the equation of the reduced MLR model
print(f'R-squared : {model3.summary2().tables[0][1][6]} ***** Adjusted. R-squared :{model3.summary2().tables[0][3][0]} ')
equation = model3.summary2().tables[1] 
print(f'Predicted {model3.summary2().tables[0][1][1]} as Y = ')
for x in equation.itertuples():
  print(f'{x[1]:+.3f} * {x[0]}')
# Out:
# R-squared : 0.988 ***** Adjusted. R-squared :0.988
# Predicted Bandwidth_GB_Year as Y =
# +207.346 * Intercept
# +31.643 * Children
# +81.975 * Tenure
# +70.835 * Gender_Male
# +77.766 * Multiple_Yes
# +80.005 * OnlineSecurity_Yes
# +93.762 * OnlineBackup_Yes
# +83.286 * DeviceProtection_Yes
# +226.881 * StreamingTV_Yes

# %%
y_hat = model3.predict()

pd.DataFrame({'Actual': y, 'Predicted': y_hat}).head()
# Out:
#         Actual    Predicted
# 0   904.536110  1009.008750
# 1   800.982766   718.460882
# 2  2054.706961  1703.128192
# 3  2164.579412  2017.432735
# 4   271.493436   642.040386

# %%
#Lets visualize the mulile linear regression
plt.figure(figsize= (12, 4))
sns.kdeplot(data= churn_df , x = 'Bandwidth_GB_Year' , Label='Actual')
sns.kdeplot(data= df3 , x = y_hat, Label='Predicted')
plt.title('Actual Vs Predicted Bandwidth', size = 15)
plt.show()

# %%
# Updated reduced MLR Performance
print('Root Mean Squared Error = ', mean_squared_error(y, y_hat, squared=False))
print('Mean Absolute Error = ', mean_absolute_error(y, y_hat))
print('R-Squarred = ', r2_score(y, y_hat))
print(f'Residual Error is {np.sqrt(model3.mse_resid)}')
# Out:
# Root Mean Squared Error =  234.82599813738605
# Mean Absolute Error =  198.0140076847467
# R-Squarred =  0.9884517626817787
# Residual Error is 234.9317412184832
